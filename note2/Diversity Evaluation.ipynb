# %%
import matplotlib.pyplot as plt  
# %matplotlib inline
import numpy as np  
from sklearn.cluster import KMeans
# Out:
# /home/acevedo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
gan_samples = pd.read_csv("../data/2N_faster_gan/46293_3_data/gan_samples_46293_3.csv", header=None) .values

# %%
gan_samples.shape
# Out:
# (46293, 100)

# %%
kmeans = KMeans(n_clusters=10)  
kmeans.fit(gan_samples)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.23642768e-02, 8.10438357e-03, 1.34741503e-02, 7.76482194e-03,
#         6.55225928e-03, 2.92491691e-03, 6.23955940e-15, 1.39717437e-02,
#         1.42220428e-02, 1.48952765e-02, 1.37266276e-02, 5.65225515e-03,
#         1.59325667e-02, 9.29823744e-03, 7.97030451e-03, 1.37689191e-02,
#         2.24123933e-03, 7.58069005e-03, 5.58156953e-03, 2.61102008e-03,
#         1.74293999e-02, 1.55673061e-02, 1.44575686e-03, 1.66097063e-02,
#         5.79018118e-03, 1.65483211e-02, 1.42931647e-02, 1.91900883e-03,
#         1.44506400e-02, 3.15033959e-03, 5.94246176e-03, 9.70118691e-03,
#         8.47262521e-03, 1.59771950e-02, 1.01026979e-16, 1.60204841e-02,
#         1.49780790e-02, 1.19118803e-02, 1.79502570e-02, 4.64965245e-16,
#         3.51003028e-03, 1.42294401e-02, 1.01835876e-02, 1.71861063e-02,
#         1.13036241e-02, 3.16190060e-03, 8.55090234e-03, 2.92801619e-14,
#         7.85324201e-03, 1.74638117e-02, 1.75046189e-02, 7.96075655e-03,
# ...
