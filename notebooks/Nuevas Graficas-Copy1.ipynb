# %%
import pandas as pd
from plot_utils import  *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#k1_gan = pd.read_csv('gans_jsd_record/original.csv')
#k2_gan = pd.read_csv('gans_jsd_record/k2_2000_old.csv')

k3_gan = pd.read_csv('gans_jsd_record/low_lr_k3_2000_epochs.csv')
k4_gan = pd.read_csv('gans_jsd_record/low_lr_k3_2000_epochs.csv')

# %% [markdown]
# # K3 y K4 (nuevas)

# %%
plot_gan_curve(k3_gan, "K3 2000 epochs")
plot_gan_curve(k4_gan, "K4 2000 epochs")
plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

plt.savefig("comparacion k3.png", dpi=300)

# %%
sub =   k4_gan['id_sample_N'] == 15255
sub2 =   k4_gan['id_sample_N'] == 23640
final = np.logical_or(sub2  , sub)
fast_k4 = k4_gan[final]

# %%
low_lr_k4_gan = pd.read_csv('gans_jsd_record/low_lr_k4_2000_epochs.csv')

plot_gan_curve(low_lr_k4_gan, "K4 2000 epochs (Low LR)")
plot_gan_curve(fast_k4, "K4 2000 epochs (Moderate LR, triangular schedule)")

plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

plt.savefig("low lr k4.png", dpi=300)

# %% [markdown]
# # K3 y K4 (nuevas)

# %%
plot_gan_curve(k3_gan, "K3 2000 epochs")
plot_gan_curve(k4_gan, "K4 2000 epochs")
plot_gan_curve(low_lr_k4_gan, "K4 2000 epochs (Low LR)")

plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

plt.savefig("comparacion k3.png", dpi=300)

# %%
k3_gan[k3_gan['id_sample_N'] == 23640]
# Out:
#     Unnamed: 0  distance  id_sample_N  id_repetition
# 20          20  0.059420        23640              0
# 21          21  0.062002        23640              1
# 22          22  0.057549        23640              2
# 23          23  0.094385        23640              3
# 24          24  0.057529        23640              4

# %%
k3_gan[k3_gan['id_sample_N'] == 27881]
# Out:
#     Unnamed: 0  distance  id_sample_N  id_repetition
# 25          25  0.062464        27881              0
# 26          26  0.058305        27881              1
# 27          27  0.061941        27881              2
# 28          28  0.060268        27881              3
# 29          29  0.057830        27881              4
# 30          30  0.080891        27881              5
# 31          31  0.060629        27881              6
# 32          32  0.057856        27881              7
# 33          33  0.059445        27881              8
# 34          34  0.057743        27881              9

# %%
k4_gan[k4_gan['id_sample_N'] == 23640]
# Out:
#     Unnamed: 0  distance  id_sample_N  id_repetition
# 20          20  0.085445        23640              0
# 21          21  0.076611        23640              1
# 22          22  0.085888        23640              2
# 23          23  0.078770        23640              3
# 24          24  0.067173        23640              4
# 25          25  0.081220        23640              5
# 26          26  0.061937        23640              6
# 27          27  0.077202        23640              7
# 28          28  0.082141        23640              8
# 29          29  0.076252        23640              9

# %%
k4_gan[k4_gan['id_sample_N'] == 27881]
# Out:
#     Unnamed: 0  distance  id_sample_N  id_repetition
# 30          30  0.057223        27881              0
# 31          31  0.060837        27881              1
# 32          32  0.060995        27881              2
# 33          33  0.079768        27881              3
# 34          34  0.102540        27881              4
# 35          35  0.057054        27881              5
# 36          36  0.076146        27881              6

# %% [markdown]
# # Todas

# %%
plot_gan_curve(k1_gan, "K1 1000 epochs")
plot_gan_curve(k2_gan, "K2 1000 epochs")
plot_gan_curve(k3_gan, "K3 2000 epochs")
plot_gan_curve(k4_gan, "K4 2000 epochs")
plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

plt.savefig("comparacion k3.png", dpi=300)

# %%
# k4_gan

# %%
filtered_df = k4_gan[k4_gan['id_sample_N'] ==49478]
print(filtered_df)
jsd_list = filtered_df['distance'].values
jsd_list
# Out:
#     Unnamed: 0  distance  id_sample_N  id_repetition
# 67          67  0.058867        49478              0
# 68          68  0.070178        49478              1
# 69          69  0.063581        49478              2
# 70          70  0.064692        49478              3
# 71          71  0.067245        49478              4
# 72          72  0.061070        49478              5
# 73          73  0.057891        49478              6
# 74          74  0.067319        49478              7
# 75          75  0.066480        49478              8
# 76          76  0.078512        49478              9
# array([0.05886689, 0.07017756, 0.06358102, 0.06469196, 0.06724542,
#        0.06106993, 0.05789078, 0.06731868, 0.06648027, 0.07851154])

# %%
print(jsd_list.mean())
print(jsd_list.std())
# Out:
# 0.0655834064039108
# 0.005694598127665807

# %%
# !ls
# Out:
#  archieve	      'Graficas Dirichlet.ipynb'   plot_utils.py
# 'comparacion k3.png'   misc_archieve		   __pycache__
#  gans_jsd_record      'Nuevas Graficas.ipynb'	   resources
