# %%
import pandas as pd
from plot_utils import build_table, plot_gan_curve, build_table2
import matplotlib.pyplot as plt
# %matplotlib inline

train_set = pd.read_csv('../data/experiment_march_21/train_set.csv', header=None) .values
test_set = pd.read_csv('../data/experiment_march_21/test_set.csv', header=None) .values
# Out:
# /home/acevedo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
train_set.shape
# Out:
# (70000, 100)

# %%
tabla_train  = build_table('../data/plot2', train_set)
tabla_test = build_table2('../data/plot2', test_set)

# %%
print(train_set.shape)
tabla_train
# Out:
# (70000, 100)
#         DKL  id_sample_N  id_repetition
# 0  0.006286          300              0
# 1  0.005324          300              1
# 2  0.004088          400              0
# 3  0.003329          400              1
# 4  0.003300          500              0
# 5  0.002804          500              1
# 6  0.002339          700              0
# 7  0.001945          700              1

# %%
print(test_set.shape)
tabla_test
# Out:
# (20000, 100)
#         DKL  id_sample_N  id_repetition
# 0  0.006488          300              0
# 1  0.006488          300              1
# 2  0.004539          400              0
# 3  0.004539          400              1
# 4  0.004103          500              0
# 5  0.004103          500              1
# 6  0.002941          700              0
# 7  0.002941          700              1

# %%
plot_gan_curve(tabla_test, debug_flag= True)
plt.ylabel("DKL(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("DKL(GAN,Test) - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# Standard error of the mean [0. 0. 0. 0.]

# %%
plot_gan_curve(tabla_train, debug_flag=True)
plt.ylabel("DKL(GAN,Training)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("DKL(GAN,Training) - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# Standard error of the mean [0.00034006 0.0002684  0.00017552 0.00013915]
