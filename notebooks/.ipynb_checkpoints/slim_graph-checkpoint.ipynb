# %%
import pandas as pd
from plot_utils import build_table, plot_gan_curve, build_table2
import numpy as np

# %matplotlib widget
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
from scipy.spatial.distance import jensenshannon as JSD
# Out:
# /home/acevedo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
def balancer(ds1,ds2):    
    """
    ds1 and ds2 are 1D arrays
    """
    if ds1.shape == ds2.shape:
        return ds1, ds2
    
    if ds1.shape[0] > ds2.shape[0]:
        return ds1[0:ds2.shape[0]], ds2
    else:
        return ds1, ds2[0:ds1.shape[0]]

# %%
 
train_set = pd.read_csv('../data/experiment_march_21/train_set.csv', header=None) .values
test_set = pd.read_csv('../data/experiment_march_21/test_set.csv', header=None) .values

train_set.shape
# Out:
# (70000, 100)

# %%
data_path =  '../data/plot4'

# %% [markdown]
# # Histogramas de Especies
#
# ## Primero cargamos un dataset de GAN

# %%
early_gan_set = pd.read_csv('../data/plot4/3363_0_data/gan_samples_3363_0.csv', header=None) .values

later_gan_set = pd.read_csv('../data/plot4/64226_3_data/gan_samples_64226_3.csv', header=None) .values

# %% [markdown]
# ## Histograma GAN (Early)-Test Set

# %%
esp = 5

a,b = balancer(early_gan_set[:,esp],test_set[:,esp] )

sns.distplot(a, label='GAN')
sns.distplot(b, label ='Test Set')
plt.legend()

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

assert a.shape == b.shape

m = str(early_gan_set.shape[0])
plt.title("Histograma GAN (#"+m+")- Test Set para la especie #"+str(esp),fontsize=25)
print("Los datasets del histograma tienen "+str(a.shape[0])+" muestras")
print("JSD(GAN, Test Set) = "+str(JSD(a,b)))


plt.xlim(0,0.04)
plt.ylim(0,200)
# Out:
# Los datasets del histograma tienen 3363 muestras
# JSD(GAN, Test Set) = 0.6776084666942597
# (0, 200)

# %% [markdown]
# ## Histograma GAN (Later)-Test Set

# %%
esp = 5

a,b = balancer(later_gan_set[:,esp],test_set[:,esp] )

sns.distplot(a, label='GAN')
sns.distplot(b, label ='Test Set')
plt.legend()

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

m = str(later_gan_set.shape[0])
plt.title("Histograma GAN (#"+m+")- Test Set para la especie #"+str(esp),fontsize=25)
assert a.shape == b.shape
print("Los datasets del histograma tienen "+str(a.shape[0])+" muestras")
print("JSD(GAN, Test Set) = "+str(JSD(a,b)))


plt.xlim(0,0.04)
plt.ylim(0,50)
# Out:
# Los datasets del histograma tienen 20000 muestras
# JSD(GAN, Test Set) = 0.7245869375866214
# (0, 50)

# %% [markdown]
# ## Histograma Trainset-Test Set

# %%
esp = 5


a,b = balancer(test_set[:,esp],train_set[:,esp] )

sns.distplot(a, label='Test Set')
sns.distplot(b, label ='Train Set')
plt.legend()


fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

plt.title("Histograma Train Set - Test Set para la especie #"+str(esp),fontsize=25)


assert a.shape == b.shape
print("Los datasets del histograma tienen "+str(a.shape[0])+" muestras")
print("JSD(Train Set, Test Set) = "+str(JSD(a,b)))

# lims
plt.xlim(0,0.04)
plt.ylim(0,50)
# Out:
# Los datasets del histograma tienen 20000 muestras
# JSD(Train Set, Test Set) = 0.7298855586884624
# (0, 50)

# %% [markdown]
# # Tablas de JSD por subdataset y Graficas
#
# ## JSD Score
#
#
# $$S = e^{\frac{1}{N} \sum_{n=0}^{N}  x}$$
# Donde
#
# $$\vec x = {JSD(GAN_k, Testset_k)}$$

# %%
tabla_train  = build_table(data_path, train_set)
# Out:
# Table Building progress 0.0%
# Table Building progress 10.0%
# Table Building progress 20.0%
# Table Building progress 30.0%
# Table Building progress 40.0%
# Table Building progress 50.0%
# Table Building progress 60.0%
# Table Building progress 70.0%
# Table Building progress 80.0%
# Table Building progress 90.0%

# %%
tabla_test = build_table2(data_path, test_set)
# Out:
# Table Building progress 0.0%
# Table Building progress 10.0%
# Table Building progress 20.0%
# Table Building progress 30.0%
# Table Building progress 40.0%
# Table Building progress 50.0%
# Table Building progress 60.0%
# Table Building progress 70.0%
# Table Building progress 80.0%
# Table Building progress 90.0%

# %%
print(train_set.shape)
tabla_train
# Out:
# (70000, 100)
#          JSD  id_sample_N  id_repetition
# 0   1.767839        12526              0
# 1   1.759227        12526              1
# 2   1.759796        12526              2
# 3   1.758217        12526              3
# 4   1.760253        12526              4
# 5   1.766207        16193              0
# 6   1.767975        16193              1
# 7   1.767116        16193              2
# 8   1.767678        16193              3
# 9   1.769974        16193              4
# 10  1.779727        20839              0
# 11  1.779565        20839              1
# 12  1.778749        20839              2
# 13  1.778450        20839              3
# 14  1.779575        20839              4
# 15  1.780772        21502              0
# 16  1.780257        21502              1
# 17  1.783515        21502              2
# 18  1.775643        21502              3
# 19  1.778994        21502              4
# 20  1.786611        25581              0
# 21  1.784857        25581              1
# 22  1.789689        25581              2
# 23  1.790243        25581              3
# 24  1.786347        25581              4
# 25  1.797373        30633              0
# 26  1.790452        30633              1
# 27  1.797526        30633              2
# 28  1.795959        30633              3
# 29  1.789794        30633              4
# 30  1.728175         3363              0
# 31  1.731458         3363              1
# 32  1.730017         3363              2
# 33  1.732718         3363              3
# 34  1.730679         3363              4
# 35  1.800815        46293              0
# 36  1.805817        46293              1
# 37  1.806896        46293              2
# 38  1.803218        46293              3
# 39  1.801734        46293              4
# 40  1.805708        50325              0
# 41  1.806808        50325              1
# 42  1.806822        50325              2
# 43  1.801703        50325              3
# 44  1.806211        50325              4
# 45  1.811937        64226              0
# 46  1.800148        64226              1
# 47  1.806484        64226              2
# 48  1.810139        64226              3
# 49  1.806462        64226              4

# %%
print(test_set.shape)
tabla_test
# Out:
# (20000, 100)
#          JSD  id_sample_N  id_repetition
# 0   1.768230        12526              0
# 1   1.760159        12526              1
# 2   1.760197        12526              2
# 3   1.759800        12526              3
# 4   1.759865        12526              4
# 5   1.766899        16193              0
# 6   1.769059        16193              1
# 7   1.767650        16193              2
# 8   1.767943        16193              3
# 9   1.771085        16193              4
# 10  1.780135        20839              0
# 11  1.779060        20839              1
# 12  1.779440        20839              2
# 13  1.778254        20839              3
# 14  1.779711        20839              4
# 15  1.780647        21502              0
# 16  1.779634        21502              1
# 17  1.782819        21502              2
# 18  1.775811        21502              3
# 19  1.779645        21502              4
# 20  1.786920        25581              0
# 21  1.785180        25581              1
# 22  1.789911        25581              2
# 23  1.789896        25581              3
# 24  1.787585        25581              4
# 25  1.798545        30633              0
# 26  1.790638        30633              1
# 27  1.797526        30633              2
# 28  1.795395        30633              3
# 29  1.790207        30633              4
# 30  1.728344         3363              0
# 31  1.733256         3363              1
# 32  1.729624         3363              2
# 33  1.731820         3363              3
# 34  1.729850         3363              4
# 35  1.801431        46293              0
# 36  1.806044        46293              1
# 37  1.807420        46293              2
# 38  1.803628        46293              3
# 39  1.801595        46293              4
# 40  1.805850        50325              0
# 41  1.807647        50325              1
# 42  1.807024        50325              2
# 43  1.801971        50325              3
# 44  1.805634        50325              4
# 45  1.812286        64226              0
# 46  1.800039        64226              1
# 47  1.806117        64226              2
# 48  1.809626        64226              3
# 49  1.805969        64226              4

# %%
plot_gan_curve(tabla_test, debug_flag= True)
plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("JSD(GAN,Test) - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# Standard error of the mean [0.0007784  0.00147302 0.00065071 0.00028531 0.00101506 0.00081201
#  0.00154474 0.00106557 0.00088196 0.00184335]

# %%
plot_gan_curve(tabla_train, debug_flag=True)
plt.ylabel("JSD(GAN,Training)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("JSD(GAN,Training) - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# Standard error of the mean [0.00067671 0.0015446  0.0005578  0.00022956 0.00114674 0.00092545
#  0.00151901 0.00104135 0.00085823 0.00180811]
