# %%
import pandas as pd
from plot_utils import  *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /home/acevedo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
def save_df_to_dsk(data_df, name:str):
    with open(name+'.csv', 'a') as f:
        data_df.to_csv(f)

# %%
orignial_gan = pd.read_csv('gans_jsd_record/original.csv')
faster_gan = pd.read_csv('gans_jsd_record/faster.csv')
gan_5l = pd.read_csv('gans_jsd_record/5L.csv')
gan_6l = pd.read_csv('gans_jsd_record/6L.csv')
gan_2N = pd.read_csv('gans_jsd_record/2N Faster.csv')

# %%
plot_gan_curve(orignial_gan, "original")
plot_gan_curve(faster_gan, "faster")
plot_gan_curve(gan_5l, "5L")
plot_gan_curve(gan_6l, "6L")
plot_gan_curve(gan_2N, "2N Faster")

plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.xlim(3000,10000)
#plt.xlim(5000,18000)

# %%
"""

k2_train_set = pd.read_csv('../data/k2_dir/train_set.csv', header=None) .values

k2_train_set_noisy_high = pd.read_csv('../data/k2_dir/noisy_high_train.csv', header=None) .values
k2_test_set_noisy_high = pd.read_csv('../data/k2_dir/noisy_high_test.csv', header=None) .values

k2_train_set_noisy_low = pd.read_csv('../data/k2_dir/noisy_low_train.csv', header=None) .values
k2_test_set_noisy_low = pd.read_csv('../data/k2_dir/noisy_low_train.csv', header=None) .values

"""

k2_test_set = pd.read_csv('../data/k2_dir/test_set.csv', header=None) .values
k3_test_set = pd.read_csv('../data/k3_dir/k3_test_set.csv', header=None) .values

# %% [raw]
# k2_gan = build_table2( '../data/k2_retrain_net', k2_test_set)

# %%
orignial_gan = pd.read_csv('gans_jsd_record/original.csv')

# %%
k2_gan_low_noise = build_table2( '../data/k2_2N_low_noise_faster_gan', k2_test_set)

# %%
pre_k3_gan = build_table2( '../data/k3_2N_faster_gan', k3_test_set)
pre_k2_gan = build_table2( '../data/k2_2N_faster_gan', k2_test_set)

# %% [raw]
# k3_gan = build_table2( '../data/redo_k3', k3_test_set)

# %% [raw]
# save_df_to_dsk(k3_gan, "k3_2000_epochs")
# save_df_to_dsk(k2_gan, "k2_2000_epochs")

# %%
rep_k3_gan = build_table2( '../data/rep_k3', k3_test_set)

# %%
plot_gan_curve(k2_gan, "K2")
plot_gan_curve(k2_gan_high_noise.dropna(), "K2 (trained with high nosie)")
plot_gan_curve(k2_gan_low_noise.dropna(), "K2 (trained with low noise)")


plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %%
k4_test_set = pd.read_csv('../data/k4_dir/k4_test_set.csv', header=None) .values

k4_gan = build_table2( '../data/k4_gan/', k4_test_set)
save_df_to_dsk(k4_gan, "k4_2000_epochs")

# %% [markdown]
# # Combined Dirichlets: k=1,2,3

# %%
orignial_gan = pd.read_csv('gans_jsd_record/original.csv')
k2_gan = pd.read_csv('gans_jsd_record/k2_2000_epochs.csv')
k3_gan = pd.read_csv('gans_jsd_record/k3_2000_epochs.csv')

# %%
k3_plus = build_table2( '../data/k3_retrain_net_rep', k3_test_set)
# Out:
# Table Building progress 0.0%
# Table Building progress 4.95%
# Table Building progress 9.9%
# Table Building progress 14.85%
# Table Building progress 19.8%
# Table Building progress 24.75%
# Table Building progress 29.7%
# Table Building progress 34.65%
# Table Building progress 39.6%
# Table Building progress 44.55%
# Table Building progress 49.5%
# Table Building progress 54.46%
# Table Building progress 59.41%
# Table Building progress 64.36%
# Table Building progress 69.31%
# Table Building progress 74.26%
# Table Building progress 79.21%
# Table Building progress 84.16%
# Table Building progress 89.11%
# Table Building progress 94.06%
# Table Building progress 99.01%

# %%
#plot_gan_curve(orignial_gan, "K1")

plot_gan_curve(k2_gan, "K2")
plot_gan_curve(k3_plus, "K3")
# plot_gan_curve(k4_gan, "K4")

#plot_gan_curve(pre_k2_gan, "under K2")
#plot_gan_curve(pre_k3_gan, "under K3")

plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.xlim(4000,10000)
#plt.savefig("_weird combined dirichlets.png", dpi=300)

# %%
plot_gan_curve(k3_gan, "K3 (2000 epochs)")
#plot_gan_curve(rep_k3_gan, "K3  (2 rep)(2000 epochs)")
plot_gan_curve(pre_k3_gan, "under K3  (1000 epochs)")

plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3ec4f2f355cd> in <module>()
#       1 plot_gan_curve(k3_gan, "K3 (2000 epochs)")
#       2 #plot_gan_curve(rep_k3_gan, "K3  (2 rep)(2000 epochs)")
# ----> 3 plot_gan_curve(pre_k3_gan, "under K3  (1000 epochs)")
#       4
#       5 plt.ylabel("JSD(GAN,Test)",fontsize=40)
#
# NameError: name 'pre_k3_gan' is not defined

# %%
plot_gan_curve(rep_k3_gan, "K3  (2 rep)(2000 epochs)", debug_flag=True)


plt.ylabel("JSD(GAN,Test)",fontsize=40)
plt.xlabel("#Samples used to train",fontsize=40)
plt.title("GAN JSD - Samples",fontsize=40)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %%
k3_train_set = pd.read_csv('../data/k3_dir/k3_train_set.csv', header=None) .values

# %%
sns.distplot(k3_train_set.mean(axis=0), label="train")
sns.distplot(k3_test_set.mean(axis=0), label="test")
plt.legend()

# %%
sns.distplot(k3_test_set.mean(axis=0), label="test")
sns.distplot(gan_samples.mean(axis=0), label="samples")

plt.legend()

# %%
gan_samples  = pd.read_csv('../data/retrain_net/27881_1_data/gan_samples_27881_1.csv', header=None) .values

# %%
k3_train_set.sum(axis=1)
